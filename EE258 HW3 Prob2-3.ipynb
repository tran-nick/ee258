# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2C4D-7533
#
#  Directory of C:\Users\tickn\ml
#
# 10/18/2021  07:57 PM    <DIR>          .
# 10/18/2021  07:57 PM    <DIR>          ..
# 10/18/2021  07:53 PM    <DIR>          .ipynb_checkpoints
# 09/28/2021  10:22 PM    <DIR>          __pycache__
# 09/28/2021  10:16 PM            81,912 Capture.PNG
# 09/20/2021  09:51 PM            14,668 EE258 HW1 Problem 1.ipynb
# 09/20/2021  09:51 PM           158,667 EE258 HW1.ipynb
# 10/18/2021  07:55 PM             2,186 EE258 HW3.ipynb
# 09/20/2021  09:54 PM         1,423,529 housing.csv
# 09/06/2021  01:58 PM               856 Housing.ipynb
# 09/20/2021  07:25 PM           416,957 Housing_Sep8_F21.ipynb
# 10/01/2021  08:20 PM           167,294 HW2Q3.ipynb
# 10/18/2021  07:55 PM         3,522,075 HW3_paper.pdf
# 10/18/2021  07:57 PM           231,181 HW3_Readme.pdf
# 10/18/2021  07:55 PM             1,793 HW3_Readme.txt
# ...

# %%
import pandas as pd
regress = pd.read_excel('HW3_RegressionDataSet.xlsx')

# %%
regress
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %%
x = regress['AT']
y = regress['PE']

# %%
len(x)
# Out:
# 9568

# %%
import numpy as np
X_b = np.c_[np.ones((len(x),1)),x]  #numpy.c_ = <numpy.lib.index_tricks.CClass object>

# %%
theta_best= np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y) #coefficients via normal equations

# %%
print("best coefficients")
print(theta_best)
# Out:
# best coefficients
# [497.03411989  -2.17131996]

# %%
y_predict = X_b.dot(theta_best)

# %%
y_predict
# Out:
# array([464.55117331, 442.36028334, 485.9386749 , ..., 429.02837879,
#        443.88020731, 450.13360879])

# %%
import matplotlib.pyplot as plt
plt.plot(x,y,'b.',label='dataset')
plt.plot(x,y_predict,'r-',label='regression line')
plt.title('PE vs AT')
plt.xlabel("AT")
plt.ylabel("PE")
plt.legend()
plt.show()

# %%
x1 = regress['V']
X_b1 = np.c_[np.ones((len(x),1)),x1]
theta_best1= np.linalg.inv(X_b1.T.dot(X_b1)).dot(X_b1.T).dot(y)
print("best coefficients")
print(theta_best1)
y_predict1 = X_b1.dot(theta_best1)
plt.plot(x1,y,'b.',label='dataset')
plt.plot(x1,y_predict1,'r-',label='regression line')
plt.title('V vs PE')
plt.xlabel("V")
plt.ylabel("PE")
plt.legend()
plt.show()
# Out:
# best coefficients
# [517.80152631  -1.16813513]

# %%
x2 = regress['AP']
X_b2 = np.c_[np.ones((len(x2),1)),x2]
theta_best2= np.linalg.inv(X_b2.T.dot(X_b2)).dot(X_b2.T).dot(y)
print("best coefficients")
print(theta_best2)
y_predict2 = X_b2.dot(theta_best2)
plt.plot(x2,y,'b.',label='dataset')
plt.plot(x2,y_predict2,'r-',label='regression line')
plt.title('AP vs PE')
plt.xlabel("AP")
plt.ylabel("PE")
plt.legend()
plt.show()
# Out:
# best coefficients
# [-1055.26098928     1.48987167]

# %%
x3 = regress['RH']
X_b3 = np.c_[np.ones((len(x3),1)),x3]
theta_best3= np.linalg.inv(X_b3.T.dot(X_b3)).dot(X_b3.T).dot(y)
print("best coefficients")
print(theta_best3)
y_predict3 = X_b3.dot(theta_best3)
plt.plot(x3,y,'b.',label='dataset')
plt.plot(x3,y_predict3,'r-',label='regression line')
plt.title('RH vs PE')
plt.xlabel("RH")
plt.ylabel("PE")
plt.legend()
plt.show()
# Out:
# best coefficients
# [420.96176616   0.4556501 ]

# %% [markdown]
# e) the computation of linear regression using matrixes computes the inverse of X<sup>T</sup>X which has time complexity of O(n<sup>3</sup>). So when we double the number of inputs into X, our computation complexity increases cubicly.
