# %%
pwd
# Out:
# 'C:\\Users\\tickn\\ml'

# %%
import pandas as pd
iris = pd.read_csv("iris-cleaned.csv")

# %% [markdown]
# ### Problem 3, Part A

# %%
iris.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class  response
# 0  Iris-setosa         1
# 1  Iris-setosa         1
# 2  Iris-setosa         1
# 3  Iris-setosa         1
# 4  Iris-setosa         1

# %% [markdown]
# ### Problem3, Part B
#
# There are several points preventing data from being linearly seperable. The perceptron should not work because the classes are not linearly seperable.

# %%
import matplotlib.pyplot as plt
plt.scatter(iris.loc[:43,'sepal_length_cm'],iris.loc[:43,'sepal_width_cm'],color='red', marker='o',label='Iris-setosa')
plt.scatter(iris.loc[44:,'sepal_length_cm'],iris.loc[44:,'sepal_width_cm'],color='blue', marker='x',label='other')
plt.xlabel("sepal_length_cm")
plt.ylabel("sepal_width_cm")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(iris.loc[:43,'petal_length_cm'],iris.loc[:43,'petal_width_cm'],color='red', marker='o',label='Iris-setosa')
plt.scatter(iris.loc[44:,'petal_length_cm'],iris.loc[44:,'petal_width_cm'],color='blue', marker='x',label='other')
plt.xlabel("petal_length_cm")
plt.ylabel("petal_width_cm")
plt.legend()
plt.show()

# %% [markdown]
# ### Problem 3, Part C
#
# See lines where "# exp --" provides explanation of what code does.

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ### Problem 3, Part D

# %%
import numpy as np
def split_train_test(data, test_ratio):
    np.random.seed(42)
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data)*test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

iris_train_set, iris_test_set = split_train_test(iris, 0.2)
print(len(iris_train_set), "train +", len(iris_test_set), "test")
# Out:
# 116 train + 28 test

# %% [markdown]
# ### Problem 3, Part E

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2C4D-7533
#
#  Directory of C:\Users\tickn\ml
#
# 09/29/2021  11:04 PM    <DIR>          .
# 09/29/2021  11:04 PM    <DIR>          ..
# 09/28/2021  09:18 PM    <DIR>          .ipynb_checkpoints
# 09/28/2021  10:22 PM    <DIR>          __pycache__
# 09/20/2021  09:51 PM            14,668 EE258 HW1 Problem 1.ipynb
# 09/20/2021  09:51 PM           158,667 EE258 HW1.ipynb
# 09/20/2021  09:54 PM         1,423,529 housing.csv
# 09/06/2021  01:58 PM               856 Housing.ipynb
# 09/20/2021  07:25 PM           416,957 Housing_Sep8_F21.ipynb
# 09/29/2021  11:04 PM           153,331 HW2Q3.ipynb
# 09/28/2021  09:28 PM             4,852 iris-cleaned.csv
# 09/20/2021  07:56 PM             4,457 iris-data.csv
# 09/28/2021  09:15 PM             1,502 perceptron.py
#                9 File(s)      2,178,819 bytes
#                4 Dir(s)  332,144,115,712 bytes free

# %%
from perceptron import Perceptron

# %%
# create variable to hold inputs / targets
X = iris_train_set.loc[:,('sepal_length_cm','sepal_width_cm','petal_length_cm','petal_width_cm')]
X = X.to_numpy()  #gets rid of header row causing TypeError float64 to <U32
y = iris_train_set.loc[:,'response']

# %%
# create perceptron and train
pn = Perceptron()
pn.fit(X,y)

# %% [markdown]
# ### Problem 3, Part F

# %% [markdown]
# nither is the number of epochs, or times the algorithm iterates through the dataset to perform data fitting and change the weights. Yes the algorithm does converge.

# %%
pn.weight
# Out:
# array([ 0.02 ,  0.03 ,  0.106, -0.162, -0.07 ])

# %% [markdown]
# ### Problem 3, Part G

# %%
plt.scatter(pn.errors.size(),pn.errors)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-fc8d28df0a91> in <module>
# ----> 1 plt.scatter(pn.errors.size(),pn.errors)
#       2 plt.show()
#
# AttributeError: 'list' object has no attribute 'size'

# %% [markdown]
# ### Problem 3, Part H

# %% [markdown]
# ### Problem 3, Part I
