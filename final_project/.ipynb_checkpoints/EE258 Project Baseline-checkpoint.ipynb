# %% [markdown]
# # EE258 Project
#
# Dataset : https://www.kaggle.com/crowww/a-large-scale-fish-dataset
#
# Code References : https://www.tensorflow.org/tutorials/load_data/images
#
# ### Problem
# The problem we hope to solve is creating an image classification model able to identify different types of fish or seafood at local supermarkets. The model will be able to identify at least 6 different classes of fish or seafood, with all other classes considered as "other".

# %%
pwd
# Out:
# 'C:\\Users\\tickn\\ml\\final_project'

# %%
# handle imports

import cv2
import os, glob
import matplotlib.pylab as plt
from os import listdir, makedirs
from os.path import isfile, join
import pandas as pd
import PIL
import numpy as np
from imageio import imread
import io
import pathlib
# from numba import jit, cuda

# %%
import tensorflow as tf
from tensorflow import keras
print("Tensorflow Version:",tf.__version__)
print("Keras Version:",keras.__version__)
# Out:
# Tensorflow Version: 2.7.0
# Keras Version: 2.7.0

# %% [markdown]
# ### Dataset

# %%
path = 'C:/Users/tickn/ml/final_project/Fish_Dataset/Fish_Dataset_Color'
data_dir = pathlib.Path(path)

image_count = len(list(data_dir.glob('**/*.png')))
print(image_count)
# Out:
# 9000

# %% [markdown]
# The dataset is a total of 9000 445x590 pixel color images of fish with 1000 images per class. The dataset has been augmented per class with photo at different angles, rotated to generate 1000 data points per class.

# %%
batch_size = 32
img_height = 445
img_width = 590

train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split = 0.2,
    subset = "training",
    seed = 123,
    image_size = (img_height , img_width),
    batch_size = batch_size
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split = 0.2,
    subset = "validation",
    seed = 123,
    image_size = (img_height , img_width),
    batch_size = batch_size
)
# Out:
# Found 9000 files belonging to 9 classes.
# Using 7200 files for training.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9572/769309494.py in <module>
#      12 )
#      13
# ---> 14 test_ds = tf.keras.utils.image_dataset_from_directory(
#      15     data_dir,
#      16     validation_split = 0.2,
#
# E:\Users\tickn\anaconda3\envs\tf\lib\site-packages\keras\preprocessing\image_dataset.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, **kwargs)
#     183         f'Received: color_mode={color_mode}')
#     184   interpolation = image_preprocessing.get_interpolation(interpolation)
# --> 185   dataset_utils.check_validation_split_arg(
#     186       validation_split, subset, shuffle, seed)
#     187
#
# E:\Users\tickn\anaconda3\envs\tf\lib\site-packages\keras\preprocessing\dataset_utils.py in check_validation_split_arg(validation_split, subset, shuffle, seed)
#     234         'If `subset` is set, `validation_split` must be set, and inversely.')
#     235   if subset not in ('training', 'validation', None):
# --> 236     raise ValueError('`subset` must be either "training" '
#     237                      'or "validation", received: %s' % (subset,))
#     238   if validation_split and shuffle and seed is None:
#
# ValueError: `subset` must be either "training" or "validation", received: test

# %%
class_names = train_ds.class_names
for name in class_names:
    print(name)
# Out:
# Black Sea Sprat
# Gilt-Head Bream
# Hourse Mackerel
# Red Mullet
# Red Sea Bream
# Sea Bass
# Shrimp
# Striped Red Mullet
# Trout

# %%
classes = [0, 1, 2, 3, 4, 5, 6, 7, 8]
class_counts = [0, 0, 0, 0, 0, 0, 0, 0, 0]
i = 0

all_data = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    image_size = (img_height , img_width),
)

for all_img, all_labels in all_data:
    for cat in all_labels:
        class_counts[cat]+=1

print(class_counts)
distribution_data = dict(zip(classes,class_counts))
plt.bar(list(distribution_data.keys()),distribution_data.values(),width =0.6)
plt.title('All Data')
plt.xlabel('Class Category')
plt.ylabel('Counts')
plt.show()
# Out:
# Found 9000 files belonging to 9 classes.
# [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]

# %% [markdown]
# #### Outliers
#
# Originally, the dataset provided 2000 images per class. 1000 images were rgb photos of the fish at different angles, augmented by rotating the images around. The other 1000 images per class were black and white photos of the fish outline. These outline images were removed from the dataset resulting in the useful dataset of 9000 rbg images, with 1000 images per class.

# %% [markdown]
# ### Visualization of Dataset
#
# Below is visualization of each unique class of the dataset and respective class name. Rotated photos illustrate data augmentation done on original photos.

# %%
unique = []
i=0
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for item in range(len(labels)):
        if labels[item] in unique:
            continue
        else:
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(images[item].numpy().astype("uint8"))
            plt.title(class_names[labels[item]])
            plt.axis("off")

            i+=1
            unique.append(labels[item])
        
    break # run only once through a batch
